# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: annotated-types==0.6.0 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: anyio==3.7.1 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (3.7.1)
# Requirement already satisfied: asyncio==3.4.3 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (3.4.3)
# Requirement already satisfied: certifi==2023.11.17 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (2023.11.17)
# Requirement already satisfied: click==8.1.7 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (8.1.7)
# Requirement already satisfied: distro==1.8.0 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: exceptiongroup==1.2.0 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: fastapi==0.104.1 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (0.104.1)
# Requirement already satisfied: h11==0.14.0 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (0.14.0)
# Requirement already satisfied: httpcore==1.0.2 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (1.0.2)
# Requirement already satisfied: httpx==0.25.2 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (0.25.2)
# Requirement already satisfied: idna==3.6 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (3.6)
# Requirement already satisfied: openai==1.3.6 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (1.3.6)
# Requirement already satisfied: pydantic==2.5.2 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (2.5.2)
# Requirement already satisfied: pydantic_core==2.14.5 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 15)) (2.14.5)
# Requirement already satisfied: sniffio==1.3.0 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 16)) (1.3.0)
# Requirement already satisfied: sse-starlette==1.8.2 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 17)) (1.8.2)
# Requirement already satisfied: starlette==0.27.0 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 18)) (0.27.0)
# Requirement already satisfied: tqdm==4.66.1 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 19)) (4.66.1)
# Requirement already satisfied: typing_extensions==4.8.0 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 20)) (4.8.0)
# Requirement already satisfied: uvicorn==0.24.0.post1 in /Users/mike/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 21)) (0.24.0.post1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install websockets
# Out:
# Requirement already satisfied: websockets in /Users/mike/anaconda3/lib/python3.11/site-packages (13.0.1)

# %%
# !pip install sqlalchemy
# !pip install databases
# !pip install sqlite
# Out:
# Requirement already satisfied: sqlalchemy in /Users/mike/anaconda3/lib/python3.11/site-packages (2.0.33)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/mike/anaconda3/lib/python3.11/site-packages (from sqlalchemy) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/mike/anaconda3/lib/python3.11/site-packages (from sqlalchemy) (2.0.1)
# Requirement already satisfied: databases in /Users/mike/anaconda3/lib/python3.11/site-packages (0.9.0)
# Requirement already satisfied: sqlalchemy>=2.0.7 in /Users/mike/anaconda3/lib/python3.11/site-packages (from databases) (2.0.33)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/mike/anaconda3/lib/python3.11/site-packages (from sqlalchemy>=2.0.7->databases) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/mike/anaconda3/lib/python3.11/site-packages (from sqlalchemy>=2.0.7->databases) (2.0.1)
# ERROR: Could not find a version that satisfies the requirement sqlite (from versions: none)
# ERROR: No matching distribution found for sqlite

# %%
# !pip install jinja2 itsdangerous
# Out:
# Requirement already satisfied: jinja2 in /Users/mike/anaconda3/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: itsdangerous in /Users/mike/anaconda3/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mike/anaconda3/lib/python3.11/site-packages (from jinja2) (2.1.1)

# %%
# !uvicorn ai_chat:app --reload
# Out:
# INFO:     Will watch for changes in these directories: ['/Users/mike/exam']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [19951] using StatReload
# Process SpawnProcess-1:
# Traceback (most recent call last):
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/_subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 61, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 68, in serve
#     config.load()
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/config.py", line 467, in load
#     self.loaded_app = import_from_string(self.app)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/mike/exam/ai_chat.py", line 113
#     return html_dir.TemplateResponse("session_created.html", {"request": request})
#     ^^^^^^
# IndentationError: expected an indented block after 'except' statement on line 112
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# Process SpawnProcess-2:
# Traceback (most recent call last):
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/_subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 61, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 68, in serve
#     config.load()
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/config.py", line 467, in load
#     self.loaded_app = import_from_string(self.app)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/mike/exam/ai_chat.py", line 113
#     return html_dir.TemplateResponse("session_created.html", {"request": request})
#     ^^^^^^
# IndentationError: expected an indented block after 'except' statement on line 112
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# Process SpawnProcess-3:
# Traceback (most recent call last):
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/_subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 61, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 68, in serve
#     config.load()
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/config.py", line 467, in load
#     self.loaded_app = import_from_string(self.app)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/mike/exam/ai_chat.py", line 107
#     return html_dir.TemplateResponse("session_created.html", {"request": request})
#     ^^^^^^
# IndentationError: expected an indented block after 'except' statement on line 106
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# Process SpawnProcess-4:
# Traceback (most recent call last):
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/_subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 61, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 68, in serve
#     config.load()
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/config.py", line 467, in load
#     self.loaded_app = import_from_string(self.app)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/mike/exam/ai_chat.py", line 101
#     return html_dir.TemplateResponse("session_created.html", {"request": request})
#     ^^^^^^
# IndentationError: expected an indented block after 'except' statement on line 100
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# Process SpawnProcess-5:
# Traceback (most recent call last):
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/_subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 61, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 68, in serve
#     config.load()
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/config.py", line 467, in load
#     self.loaded_app = import_from_string(self.app)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/mike/exam/ai_chat.py", line 99
#     return html_dir.TemplateResponse("session_created.html", {"request": request})
#     ^^^^^^
# IndentationError: expected an indented block after 'except' statement on line 98
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# Process SpawnProcess-6:
# Traceback (most recent call last):
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/_subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 61, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 68, in serve
#     config.load()
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/config.py", line 467, in load
#     self.loaded_app = import_from_string(self.app)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/mike/exam/ai_chat.py", line 92
#     return html_dir.TemplateResponse("session_created.html", {"request": request})
#     ^^^^^^
# IndentationError: expected an indented block after 'except' statement on line 91
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# Process SpawnProcess-7:
# Traceback (most recent call last):
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/_subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 61, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 68, in serve
#     config.load()
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/config.py", line 467, in load
#     self.loaded_app = import_from_string(self.app)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/mike/exam/ai_chat.py", line 87
#     return html_dir.TemplateResponse("session_created.html", {"request": request})
#     ^^^^^^
# IndentationError: expected an indented block after 'except' statement on line 86
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# Process SpawnProcess-8:
# Traceback (most recent call last):
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/_subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 61, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 68, in serve
#     config.load()
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/config.py", line 467, in load
#     self.loaded_app = import_from_string(self.app)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/mike/exam/ai_chat.py", line 84
#     return html_dir.TemplateResponse("session_created.html", {"request": request})
#     ^^^^^^
# IndentationError: expected an indented block after 'except' statement on line 83
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# Process SpawnProcess-9:
# Traceback (most recent call last):
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/_subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 61, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 68, in serve
#     config.load()
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/config.py", line 467, in load
#     self.loaded_app = import_from_string(self.app)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/mike/exam/ai_chat.py", line 80
#     return html_dir.TemplateResponse("session_created.html", {"request": request})
#     ^^^^^^
# IndentationError: expected an indented block after 'except' statement on line 79
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# Process SpawnProcess-10:
# Traceback (most recent call last):
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/_subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 61, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 68, in serve
#     config.load()
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/config.py", line 467, in load
#     self.loaded_app = import_from_string(self.app)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/mike/exam/ai_chat.py", line 77
#     return html_dir.TemplateResponse("session_created.html", {"request": request})
#     ^^^^^^
# IndentationError: expected an indented block after 'except' statement on line 76
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# Process SpawnProcess-11:
# Traceback (most recent call last):
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/_subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 61, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 68, in serve
#     config.load()
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/config.py", line 467, in load
#     self.loaded_app = import_from_string(self.app)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/mike/exam/ai_chat.py", line 74
#     return html_dir.TemplateResponse("session_created.html", {"request": request})
#     ^^^^^^
# IndentationError: expected an indented block after 'except' statement on line 73
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# Process SpawnProcess-12:
# Traceback (most recent call last):
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/_subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 61, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 68, in serve
#     config.load()
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/config.py", line 467, in load
#     self.loaded_app = import_from_string(self.app)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/mike/exam/ai_chat.py", line 71
#     return html_dir.TemplateResponse("session_created.html", {"request": request})
#     ^^^^^^
# IndentationError: expected an indented block after 'except' statement on line 70
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# Process SpawnProcess-13:
# Traceback (most recent call last):
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/_subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 61, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 68, in serve
#     config.load()
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/config.py", line 467, in load
#     self.loaded_app = import_from_string(self.app)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/mike/exam/ai_chat.py", line 71
#     return html_dir.TemplateResponse("session_created.html", {"request": request})
#     ^^^^^^
# IndentationError: expected an indented block after 'except' statement on line 70
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# Process SpawnProcess-14:
# Traceback (most recent call last):
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/_subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 61, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 68, in serve
#     config.load()
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/config.py", line 467, in load
#     self.loaded_app = import_from_string(self.app)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/mike/exam/ai_chat.py", line 69
#     return html_dir.TemplateResponse("session_created.html", {"request": request})
#     ^^^^^^
# IndentationError: expected an indented block after 'except' statement on line 68
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# Process SpawnProcess-15:
# Traceback (most recent call last):
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/_subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 61, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 68, in serve
#     config.load()
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/config.py", line 467, in load
#     self.loaded_app = import_from_string(self.app)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/mike/exam/ai_chat.py", line 68
#     return html_dir.TemplateResponse("session_created.html", {"request": request})
#     ^^^^^^
# IndentationError: expected an indented block after 'except' statement on line 67
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# INFO:     Started server process [20141]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [20141]
# Process SpawnProcess-17:
# Traceback (most recent call last):
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Users/mike/anaconda3/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/_subprocess.py", line 76, in subprocess_started
#     target(sockets=sockets)
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 61, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/server.py", line 68, in serve
#     config.load()
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/config.py", line 467, in load
#     self.loaded_app = import_from_string(self.app)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/site-packages/uvicorn/importer.py", line 21, in import_from_string
#     module = importlib.import_module(module_str)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mike/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1147, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 690, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/mike/exam/ai_chat.py", line 68
#     return html_dir.TemplateResponse("session_created.html", {"request": request})
#     ^^^^^^
# IndentationError: expected an indented block after 'except' statement on line 67
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# INFO:     Started server process [20155]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [20155]
# INFO:     Started server process [20171]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [20171]
# INFO:     Started server process [20787]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [20787]
# INFO:     Started server process [20799]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [20799]
# INFO:     Started server process [20807]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [20807]
# INFO:     Started server process [20863]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [20863]
# INFO:     Started server process [20911]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [20911]
# INFO:     Started server process [21015]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# <<<<<Funcion get_session_id_from_cookie
# <<<<<<Funcion home
# INFO:     127.0.0.1:59160 - "GET /ai_chat HTTP/1.1" 200 OK
# INFO:     ('127.0.0.1', 59162) - "WebSocket /ws" [accepted]
# INFO:     connection open
# <<<<<<Function create session
# DEBUG:root:Setting cookie for the user.
# DEBUG:root:Cookie set in response: session_id=eyJ1c2VyX2lkIjo5OTk5OX0.ZtsW-g.stCa92y4PX-nQkcqAxm6gtk0xnM; Domain=localhost:8000/ai_chat; HttpOnly; Path=/ai_chat; SameSite=Lax
# INFO:     127.0.0.1:59176 - "GET /ai_chat/create-session HTTP/1.1" 200 OK
# Error: 1006
# INFO:     connection closed
# <<<<<Funcion get_session_id_from_cookie
# <<<<<<Funcion home
# INFO:     127.0.0.1:59180 - "GET /ai_chat HTTP/1.1" 200 OK
# INFO:     ('127.0.0.1', 59182) - "WebSocket /ws" [accepted]
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': 'You are a genius AI assistant named Mikes, The Powerful. start the conversation with an introduction yourselfYou can answer in short wayYour tone is formal, You alsohave an inexplicable interest in physicsWhen you initially greet the user, tell a smart fact of physics.'}, {'role': 'user', 'content': 'Hey hello'}], 'model': 'gpt-3.5-turbo', 'functions': [{'name': 'SarcasmDetection', 'parameters': {'description': 'Use this function when either sarcasm is detected, or the user requests that sarcasm to be detected.', 'properties': {'quote': {'description': 'When sarcasm is detected, this is the quote of the sarcastic text.', 'title': 'Quote', 'type': 'string'}, 'score': {'description': 'A score between 0 and 9, where 0 is not sarcastic and 9 is very sarcastic.', 'title': 'Score', 'type': 'integer'}}, 'required': ['quote', 'score'], 'title': 'SarcasmDetection', 'type': 'object'}}, {'name': 'JokeExplanation', 'parameters': {'description': 'Use this function when a joke is detected, or the user requests that a joke be explained. Provide an explanation.', 'properties': {'setup': {'description': 'The initial part of the joke that sets the context. It includes background information necessary for understanding the joke.', 'title': 'Setup', 'type': 'string'}, 'premise': {'description': "The core idea or concept upon which the joke is built. It's the foundational situation or assumption that makes the joke work.", 'title': 'Premise', 'type': 'string'}, 'punchline': {'description': 'The climax of the joke, usually delivering the humor. It typically comes with a twist or surprise that contrasts with the setup or premise, creating a humorous effect.', 'title': 'Punchline', 'type': 'string'}}, 'required': ['setup', 'premise', 'punchline'], 'title': 'JokeExplanation', 'type': 'object'}}, {'name': 'JokeDelivery', 'parameters': {'description': 'Use this function when you want to tell a joke. Use some whimsy and tell jokes seemingly at random. But also tell\njokes when the user requests. Only tell clean comedy.', 'properties': {'text': {'description': 'The text of the joke.', 'title': 'Text', 'type': 'string'}}, 'required': ['text'], 'title': 'JokeDelivery', 'type': 'object'}}], 'stream': True}}
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x105a46310>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x105884d40> server_hostname='api.openai.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x105a47e10>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 06 Sep 2024 14:51:45 GMT'), (b'Content-Type', b'text/event-stream; charset=utf-8'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-organization', b'user-y6hep0upxlueqzs5hh6uodcr'), (b'openai-processing-ms', b'106'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=15552000; includeSubDomains; preload'), (b'x-ratelimit-limit-requests', b'10000'), (b'x-ratelimit-limit-tokens', b'200000'), (b'x-ratelimit-remaining-requests', b'9999'), (b'x-ratelimit-remaining-tokens', b'199911'), (b'x-ratelimit-reset-requests', b'8.64s'), (b'x-ratelimit-reset-tokens', b'26ms'), (b'x-request-id', b'req_794c3fff8eb13987c9e95bb4cad9ee68'), (b'CF-Cache-Status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8bef4767b9ce3467-DFW'), (b'alt-svc', b'h3=":443"; ma=86400')])
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/chat/completions "200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# INFO:     connection open
# WARNING:  StatReload detected changes in 'ai_chat.py'. Reloading...
# INFO:     Shutting down
# Error: 1012
# INFO:     connection closed
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [21015]
# INFO:     Started server process [21234]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
